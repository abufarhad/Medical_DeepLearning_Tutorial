# %% [markdown]
# # AutoKeras

# %% [markdown]
# - pip install autokeras
# - https://github.com/jhfjhfj1/autokeras
# - https://arxiv.org/abs/1806.10282

# %%
### Tensorflow : 1.10 

from keras.datasets import mnist
from autokeras import ImageClassifier
import tensorflow
# Out:
# /Users/dhlee/anaconda/envs/tensorflow3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ## Load MNIST data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape + (1,))
x_test = x_test.reshape(x_test.shape + (1,))

# %% [markdown]
# ## Train

# %%
clf = ImageClassifier(verbose=True, searcher_args={'trainer_args':{'max_iter_num':5}})

# %%
clf.fit(x_train, y_train, time_limit=5 * 60 * 60)
# Out:
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 0               |
# +----------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           0            |   4.942196583747863    |        0.96212         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 1               |
# +----------------------------------------------+
# /home/dhlee-volta/anaconda3/lib/python3.6/site-packages/autokeras/bayesian.py:151: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |           0            |          ('to_concat_skip_model', 1, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           1            |   3.2061469621956347   |         0.974          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 2               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |           1            |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           2            |   2.6725406674668193   |        0.97972         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 3               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |           2            |           ('to_add_skip_model', 23, 5)          |
# |                        |           ('to_add_skip_model', 1, 5)           |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           3            |   2.1071070544421673   |        0.98444         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 4               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |           3            |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |         ('to_conv_deeper_model', 21, 3)         |
# |                        |         ('to_concat_skip_model', 21, 18)        |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           4            |   2.2871345087885855   |        0.98324         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 5               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |           3            |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           5            |   1.7612414941191674   |   0.9874799999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 6               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |           5            |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |         ('to_conv_deeper_model', 21, 3)         |
# |                        |         ('to_concat_skip_model', 21, 18)        |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_add_skip_model', 54, 44)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           6            |   1.8317721204832196   |   0.9873200000000001   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |               Training model 7               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |           5            |         ('to_conv_deeper_model', 24, 3)         |
# |                        |         ('to_conv_deeper_model', 21, 3)         |
# |                        |         ('to_concat_skip_model', 21, 18)        |
# |                        |         ('to_conv_deeper_model', 18, 3)         |
# |                        |          ('to_add_skip_model', 47, 54)          |
# |                        |            ('to_wider_model', 21, 64)           |
# |                        |          ('to_add_skip_model', 24, 44)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           7            |   1.8094061460345983   |   0.9872800000000002   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 8               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |           6            |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           8            |   1.8765961933881043   |   0.9854799999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 9               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |           8            |         ('to_conv_deeper_model', 21, 3)         |
# |                        |         ('to_concat_skip_model', 21, 18)        |
# |                        |         ('to_conv_deeper_model', 18, 3)         |
# |                        |          ('to_add_skip_model', 47, 54)          |
# |                        |            ('to_wider_model', 21, 64)           |
# |                        |          ('to_add_skip_model', 24, 44)          |
# |                        |         ('to_conv_deeper_model', 47, 3)         |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |          ('to_add_skip_model', 54, 24)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           9            |   1.8294368978589772   |         0.9864         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 10               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |           6            |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |         ('to_concat_skip_model', 21, 44)        |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |            ('to_wider_model', 18, 64)           |
# |                        |           ('to_add_skip_model', 1, 18)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           10           |   2.026924802735448    |         0.9858         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 11               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |           6            |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |          ('to_dense_deeper_model', 14)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           11           |   1.9589242776855826   |   0.9869600000000001   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 12               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |           6            |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |            ('to_wider_model', 18, 64)           |
# |                        |         ('to_concat_skip_model', 47, 18)        |
# |                        |            ('to_wider_model', 5, 64)            |
# |                        |            ('to_wider_model', 5, 128)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           12           |   2.075784901715815    |   0.9854400000000002   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 13               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |           6            |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |            ('to_wider_model', 24, 64)           |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |         ('to_concat_skip_model', 21, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           13           |   1.869590962305665    |         0.9858         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 14               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |           6            |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |          ('to_add_skip_model', 21, 24)          |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           14           |   1.653213655948639    |         0.9872         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 15               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |           6            |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |         ('to_conv_deeper_model', 27, 3)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           15           |   1.8520454028621316   |        0.98708         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 16               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |           5            |         ('to_conv_deeper_model', 21, 3)         |
# |                        |         ('to_concat_skip_model', 21, 18)        |
# |                        |         ('to_conv_deeper_model', 47, 3)         |
# |                        |           ('to_add_skip_model', 47, 9)          |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |         ('to_conv_deeper_model', 18, 3)         |
# |                        |            ('to_wider_model', 63, 64)           |
# |                        |            ('to_wider_model', 21, 64)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           16           |   2.020403645001352    |        0.98612         |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 17               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |           14           |           ('to_add_skip_model', 5, 24)          |
# |                        |            ('to_wider_model', 44, 64)           |
# |                        |            ('to_wider_model', 24, 64)           |
# |                        |            ('to_wider_model', 14, 64)           |
# |                        |         ('to_concat_skip_model', 21, 5)         |
# |                        |         ('to_concat_skip_model', 18, 44)        |
# |                        |         ('to_conv_deeper_model', 44, 3)         |
# |                        |            ('to_wider_model', 18, 64)           |
# |                        |           ('to_wider_model', 24, 128)           |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           17           |   1.7905929362401367   |   0.9865999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 18               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |           6            |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |            ('to_wider_model', 24, 64)           |
# |                        |           ('to_add_skip_model', 1, 47)          |
# |                        |            ('to_wider_model', 21, 64)           |
# |                        |         ('to_concat_skip_model', 47, 5)         |
# |                        |         ('to_concat_skip_model', 21, 5)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           18           |   1.7697915555909276   |         0.9868         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 19               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |           6            |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |           ('to_add_skip_model', 5, 24)          |
# |                        |            ('to_wider_model', 5, 64)            |
# |                        |           ('to_add_skip_model', 18, 9)          |
# |                        |            ('to_wider_model', 5, 128)           |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |            ('to_wider_model', 1, 64)            |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           19           |    1.53669305536896    |   0.9890000000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 20               |
# +----------------------------------------------+
#
# +--------------------------------------------------------------------------+
# |    Father Model ID     |                 Added Operation                 |
# +--------------------------------------------------------------------------+
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |                        |          ('to_conv_deeper_model', 5, 3)         |
# |                        |          ('to_conv_deeper_model', 9, 3)         |
# |                        |           ('to_add_skip_model', 1, 18)          |
# |                        |          ('to_add_skip_model', 18, 24)          |
# |                        |          ('to_add_skip_model', 24, 27)          |
# |                        |         ('to_conv_deeper_model', 24, 3)         |
# |                        |          ('to_conv_deeper_model', 1, 3)         |
# |           19           |           ('to_add_skip_model', 5, 24)          |
# |                        |            ('to_wider_model', 24, 64)           |
# |                        |           ('to_add_skip_model', 1, 47)          |
# |                        |            ('to_wider_model', 21, 64)           |
# |                        |         ('to_concat_skip_model', 47, 5)         |
# |                        |         ('to_concat_skip_model', 21, 5)         |
# |                        |          ('to_dense_deeper_model', 14)          |
# |                        |            ('to_wider_model', 1, 64)            |
# |                        |          ('to_concat_skip_model', 1, 5)         |
# |                        |         ('to_concat_skip_model', 1, 18)         |
# +--------------------------------------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           20           |   2.102202644944191    |   0.9857600000000002   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 21               |
# +----------------------------------------------+
#
# Time limit for model search is reached. Ending the model search.

# %% [markdown]
# ## Train the best model

# %%
clf.final_fit(x_train, y_train, x_test, y_test, retrain=False, trainer_args={'max_iter_num':10})
# Out:
# Loading and training the best model recorded from the search.
# HBox(children=(IntProgress(value=0, description='Epoch-1, Current Metric - 0', layout=Layout(flex='2'), max=46…
# HBox(children=(IntProgress(value=0, description='Epoch-2, Current Metric - 0.989', layout=Layout(flex='2'), ma…
# HBox(children=(IntProgress(value=0, description='Epoch-3, Current Metric - 0.9894', layout=Layout(flex='2'), m…
# HBox(children=(IntProgress(value=0, description='Epoch-4, Current Metric - 0.9872', layout=Layout(flex='2'), m…
# HBox(children=(IntProgress(value=0, description='Epoch-5, Current Metric - 0.9903', layout=Layout(flex='2'), m…
# HBox(children=(IntProgress(value=0, description='Epoch-6, Current Metric - 0.9896', layout=Layout(flex='2'), m…
# HBox(children=(IntProgress(value=0, description='Epoch-7, Current Metric - 0.988', layout=Layout(flex='2'), ma…
# HBox(children=(IntProgress(value=0, description='Epoch-8, Current Metric - 0.9868', layout=Layout(flex='2'), m…
# HBox(children=(IntProgress(value=0, description='Epoch-9, Current Metric - 0.9882', layout=Layout(flex='2'), m…
# HBox(children=(IntProgress(value=0, description='Epoch-10, Current Metric - 0.9881', layout=Layout(flex='2'), …

# %% [markdown]
# ## Test

# %%
y = clf.evaluate(x_test, y_test)
print(y * 100)
# Out:
# 99.13

# %% [markdown]
# ## Best Model Architecture Overview

# %%
best_model = clf.load_searcher().load_best_model()

# %%
best_model.n_layers
# Out:
# 67

# %%
from torchvision import models
print(best_model.produce_model())
# Out:
# TorchModel(
#   (0): ReLU()
#   (1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (4): ReLU()
#   (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (8): ReLU()
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (12): TorchFlatten()
#   (13): Dropout2d(p=0.25)
#   (14): Linear(in_features=576, out_features=64, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=64, out_features=10, bias=True)
#   (17): ReLU()
#   (18): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (19): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): ReLU()
#   (24): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU()
#   (27): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (28): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU()
#   (30): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (31): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): TorchAdd()
#   (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (34): ReLU()
#   (35): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (36): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): TorchAdd()
#   (38): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (39): ReLU()
#   (40): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (41): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (42): TorchAdd()
#   (43): ReLU()
#   (44): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (45): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): ReLU()
#   (47): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (48): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (49): ReLU()
#   (50): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   (51): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (52): TorchAdd()
#   (53): ReLU()
#   (54): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (55): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): TorchAdd()
#   (57): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (58): TorchConcatenate()
#   (59): ReLU()
#   (60): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   (61): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (62): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (63): TorchConcatenate()
#   (64): ReLU()
#   (65): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#   (66): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# ## Save Model

# %%
import torch

torch.save(best_model, 'autoKeras_mnist.h5')
model = torch.load('autoKeras_mnist.h5')
print(model.produce_model())
# Out:
# TorchModel(
#   (0): ReLU()
#   (1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (4): ReLU()
#   (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (8): ReLU()
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (12): TorchFlatten()
#   (13): Dropout2d(p=0.25)
#   (14): Linear(in_features=576, out_features=64, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=64, out_features=10, bias=True)
#   (17): ReLU()
#   (18): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (19): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU()
#   (21): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): ReLU()
#   (24): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU()
#   (27): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (28): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU()
#   (30): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (31): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): TorchAdd()
#   (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (34): ReLU()
#   (35): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (36): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): TorchAdd()
#   (38): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (39): ReLU()
#   (40): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (41): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (42): TorchAdd()
#   (43): ReLU()
#   (44): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (45): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): ReLU()
#   (47): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (48): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (49): ReLU()
#   (50): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   (51): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (52): TorchAdd()
#   (53): ReLU()
#   (54): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (55): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): TorchAdd()
#   (57): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (58): TorchConcatenate()
#   (59): ReLU()
#   (60): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   (61): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (62): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (63): TorchConcatenate()
#   (64): ReLU()
#   (65): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#   (66): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
